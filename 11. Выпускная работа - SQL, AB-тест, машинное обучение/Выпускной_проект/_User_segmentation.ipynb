# %% [markdown]
# <h1>Оглавление<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Материалы" data-toc-modified-id="Материалы-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Материалы</a></span></li><li><span><a href="#Общая-информация-по-исходным-данным" data-toc-modified-id="Общая-информация-по-исходным-данным-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Общая информация по исходным данным</a></span></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Проверка-данных-на-пропуски,-дубликаты,-тип-данных" data-toc-modified-id="Проверка-данных-на-пропуски,-дубликаты,-тип-данных-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Проверка данных на пропуски, дубликаты, тип данных</a></span></li><li><span><a href="#Перевод-категориальных-признаков-в-бинарный-код" data-toc-modified-id="Перевод-категориальных-признаков-в-бинарный-код-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Перевод категориальных признаков в бинарный код</a></span></li></ul></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span><ul class="toc-item"><li><span><a href="#Распределения-признаков-клиентов-банка" data-toc-modified-id="Распределения-признаков-клиентов-банка-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Распределения признаков клиентов банка</a></span></li><li><span><a href="#Распределения-признаков-для-оттока-и-действующих-клиентов-банка" data-toc-modified-id="Распределения-признаков-для-оттока-и-действующих-клиентов-банка-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Распределения признаков для оттока и действующих клиентов банка</a></span></li><li><span><a href="#Распределения-признаков-по-городам" data-toc-modified-id="Распределения-признаков-по-городам-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Распределения признаков по городам</a></span></li><li><span><a href="#Корреляционный-анализ-данных" data-toc-modified-id="Корреляционный-анализ-данных-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Корреляционный анализ данных</a></span></li></ul></li><li><span><a href="#Сегментация-пользователей-на-основании-количества-потребляемых-продуктов" data-toc-modified-id="Сегментация-пользователей-на-основании-количества-потребляемых-продуктов-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Сегментация пользователей на основании количества потребляемых продуктов</a></span><ul class="toc-item"><li><span><a href="#Оценка-оттока-клиентов-для-каждого-сегмента-пользователей" data-toc-modified-id="Оценка-оттока-клиентов-для-каждого-сегмента-пользователей-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Оценка оттока клиентов для каждого сегмента пользователей</a></span></li><li><span><a href="#Портрет-клиента-для-каждого-сегмента" data-toc-modified-id="Портрет-клиента-для-каждого-сегмента-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Портрет клиента для каждого сегмента</a></span></li></ul></li><li><span><a href="#Проверка-статистических-гипотез" data-toc-modified-id="Проверка-статистических-гипотез-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Проверка статистических гипотез</a></span><ul class="toc-item"><li><span><a href="#Проверка-основной-гипотезы" data-toc-modified-id="Проверка-основной-гипотезы-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Проверка основной гипотезы</a></span></li><li><span><a href="#Проверка-дополнительной-гипотезы" data-toc-modified-id="Проверка-дополнительной-гипотезы-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Проверка дополнительной гипотезы</a></span></li></ul></li><li><span><a href="#Модель-прогнозирования-оттока-клиентов" data-toc-modified-id="Модель-прогнозирования-оттока-клиентов-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Модель прогнозирования оттока клиентов</a></span><ul class="toc-item"><li><span><a href="#Обучение-модели-на-train-выборке" data-toc-modified-id="Обучение-модели-на-train-выборке-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Обучение модели на train-выборке</a></span></li><li><span><a href="#Оценка-и-сравнение-метрик-на-валидационной-выборке" data-toc-modified-id="Оценка-и-сравнение-метрик-на-валидационной-выборке-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>Оценка и сравнение метрик на валидационной выборке</a></span></li></ul></li><li><span><a href="#Кластеризация-клиентов-банка" data-toc-modified-id="Кластеризация-клиентов-банка-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Кластеризация клиентов банка</a></span><ul class="toc-item"><li><span><a href="#Стандартизация-данных.-Матрица-расстояний-и-дендограмма" data-toc-modified-id="Стандартизация-данных.-Матрица-расстояний-и-дендограмма-8.1"><span class="toc-item-num">8.1&nbsp;&nbsp;</span>Стандартизация данных. Матрица расстояний и дендограмма</a></span></li><li><span><a href="#Прогноз-кластеров" data-toc-modified-id="Прогноз-кластеров-8.2"><span class="toc-item-num">8.2&nbsp;&nbsp;</span>Прогноз кластеров</a></span></li><li><span><a href="#Распределение-признаков-для-кластеров" data-toc-modified-id="Распределение-признаков-для-кластеров-8.3"><span class="toc-item-num">8.3&nbsp;&nbsp;</span>Распределение признаков для кластеров</a></span></li><li><span><a href="#Доля-оттока-для-каждого-кластера" data-toc-modified-id="Доля-оттока-для-каждого-кластера-8.4"><span class="toc-item-num">8.4&nbsp;&nbsp;</span>Доля оттока для каждого кластера</a></span></li></ul></li><li><span><a href="#Выводы-и-рекомендации" data-toc-modified-id="Выводы-и-рекомендации-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Выводы и рекомендации</a></span></li></ul></div>

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
# %matplotlib inline 
import seaborn as sns
import plotly.express as px
import scipy.stats as stats

# %% [markdown]
# ## Материалы

# %% [markdown]
# * Презентация https://disk.yandex.ru/i/4hV-kB4e2GzKzg

# %% [markdown]
# ## Общая информация по исходным данным

# %%
df = pd.read_csv('bank_dataset.csv')
df.columns = df.columns.str.lower()
df.head()
# Out:
#      userid  score       city gender  age  objects    balance  products  \
# 0  15677338    619  Ярославль      Ж   42        2        NaN         1
# 1  15690047    608    Рыбинск      Ж   41        1   83807.86         1
# 2  15662040    502  Ярославль      Ж   42        8  159660.80         3
# 3  15744090    699  Ярославль      Ж   39        1        NaN         2
# 4  15780624    850    Рыбинск      Ж   43        2  125510.82         1
#
#    creditcard  loyalty  estimated_salary  churn
# 0           1        1         101348.88      1
# 1           0        1         112542.58      0
# 2           1        0         113931.57      1
# 3           0        0          93826.63      0
# 4           1        1          79084.10      0

# %% [markdown]
# **Описание данных**
#
# - ***userid*** — идентификатор пользователя;
# - ***score*** — баллы кредитного скоринга;
# - ***city*** — город;
# - ***gender*** — пол;
# - ***age*** — возраст;
# - ***objects*** — количество объектов в собственности;
# - ***balance*** — баланс на счёте;
# - ***products*** — количество продуктов, которыми пользуется клиент;
# - ***creditCard*** — есть ли кредитная карта;
# - ***loyalty*** — активный клиент;
# - ***estimated_salary*** — заработная плата клиента;
# - ***churn*** — ушёл или нет.

# %% [markdown]
# ## Предобработка данных

# %% [markdown]
# ### Проверка данных на пропуски, дубликаты, тип данных

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 12 columns):
# userid              10000 non-null int64
# score               10000 non-null int64
# city                10000 non-null object
# gender              10000 non-null object
# age                 10000 non-null int64
# objects             10000 non-null int64
# balance             6383 non-null float64
# products            10000 non-null int64
# creditcard          10000 non-null int64
# loyalty             10000 non-null int64
# estimated_salary    10000 non-null float64
# churn               10000 non-null int64
# dtypes: float64(2), int64(8), object(2)
# memory usage: 937.6+ KB

# %% [markdown]
# В данных представлено 10000 строк с основной информацией по клиентам банка. Тип данных соответствует смысловой нагрузке каждого столбца - есть как количественные, так и категориальные признаки. Также видим, что **в столбце баланса на счете есть пропуски**, посмотрим, насколько их много в данных и после решим, что с ними делать.

# %%
print('Количество дубликатов в данных: {}'.format(df.duplicated().sum()))
print('Доля пропущенных значений в данных: {}%'.format((df['balance'].isna().mean() * 100).round(1)))
# Out:
# Количество дубликатов в данных: 0
# Доля пропущенных значений в данных: 36.2%

# %% [markdown]
# **Проверим, есть ли клиенты с 0 болансом**

# %%
df.query('balance == 0')
# Out:
# Empty DataFrame
# Columns: [userid, score, city, gender, age, objects, balance, products, creditcard, loyalty, estimated_salary, churn]
# Index: []

# %% [markdown]
# Пользователей с 0 балансом нет, можем предположить, что пропуски - это и есть 0 на счете. Так как пропущенных значений - треть данных, удалить мы их не можем без потери в результате анализа, поэтому заменим пропуски 0 и посмотрим на признаки для таких клиентов.

# %%
df = df.fillna(0)   
df.query('balance == 0').head()
# Out:
#       userid  score       city gender  age  objects  balance  products  \
# 0   15677338    619  Ярославль      Ж   42        2      0.0         1
# 3   15744090    699  Ярославль      Ж   39        1      0.0         2
# 6   15635267    822  Ярославль      М   50        7      0.0         2
# 11  15779909    497    Рыбинск      М   24        3      0.0         2
# 12  15675000    476  Ярославль      Ж   34       10      0.0         2
#
#     creditcard  loyalty  estimated_salary  churn
# 0            1        1         101348.88      1
# 3            0        0          93826.63      0
# 6            1        1          10062.80      0
# 11           1        0          76390.01      0
# 12           1        0          26260.98      0

# %% [markdown]
# Среди клиентов, у которых 0 баланс на счете есть те, у кого оформлена кредитная карта в банке - можем предположить, что такие клиенты оформили только кредиторский счет, поэтому их баланс нулевой. Есть также и те, у кого не офорлмена кредитная карта, но видно, что они пользуются как минимум 1 продуктом банка - видимо, у таких клиентов также нет дебиторского счета. Оставляем заполнение пропусков 0 для дальнейшего анализа.

# %% [markdown]
# ### Перевод категориальных признаков в бинарный код

# %%
def gender_bul(row):
    if row['gender'] == 'Ж':
        return '0'
    else:
        return '1'

df['gender_bul'] = df.apply(gender_bul, axis=1)
df['gender_bul'] = df['gender_bul'].astype('int')

# %%
df['city'].value_counts()
# Out:
# Ярославль         5014
# Ростов Великий    2509
# Рыбинск           2477
# Name: city, dtype: int64

# %% [markdown]
# Категоризацию признака **'city'** проведем с помощью словаря, где 1 - Ярославль, 2 - Ростов Великий, 3 - Рыбинск.

# %%
dct = {'Ярославль':1, 'Ростов Великий':2, 'Рыбинск':3}
df['city_numb'] = df['city'].map(dct)
df['city_numb'] = df['city_numb'].astype('int')

# %% [markdown]
# ## Исследовательский анализ данных

# %% [markdown]
# ### Распределения признаков клиентов банка

# %%
# оставим только количественные признаки
data = df.drop(columns=['city', 'gender', 'userid'])

for column in data.columns:
    plt.figure(figsize=(12, 5)) 
    print('Числовое описание для столбца {}:'.format(column))
    print(data[column].describe())
    
    sns.distplot(data[column])
    plt.title(column)
    plt.show()
    sns.boxplot(x=data[column], data=data) 
    plt.title(column)
    plt.show()
# Out:
# Числовое описание для столбца score:
# count    10000.000000
# mean       650.528800
# std         96.653299
# min        350.000000
# 25%        584.000000
# 50%        652.000000
# 75%        718.000000
# max        850.000000
# Name: score, dtype: float64
# Числовое описание для столбца age:
# count    10000.000000
# mean        38.921800
# std         10.487806
# min         18.000000
# 25%         32.000000
# 50%         37.000000
# 75%         44.000000
# max         92.000000
# Name: age, dtype: float64
# Числовое описание для столбца objects:
# count    10000.000000
# mean         5.012800
# std          2.892174
# min          0.000000
# 25%          3.000000
# 50%          5.000000
# 75%          7.000000
# max         10.000000
# Name: objects, dtype: float64
# Числовое описание для столбца balance:
# count     10000.000000
# mean      76485.889288
# std       62397.405202
# min           0.000000
# 25%           0.000000
# 50%       97198.540000
# 75%      127644.240000
# ...

# %% [markdown]
# Мы построили график распределения и ящик с усами для каждого признака,а также рассмотрели их числовое описание и вот какие выводы можно сделать:
#
# * **score** - у большинства клиентов банка от 584-718 баллов кредитного скоринга. Однако есть весомая часть клиентов, которые выбиваются из нормального распределения и имеют практически максимальные баллы.
# * **age** - большая часть клиентов - это зрелые люди от 32-44 лет. Но есть также и молодые клиенты 18 лет и пожилые - 92 года. Распределение данных по возрасту с положительной скошенностью, и клиенты старше 60 лет - довольно редкое явление.
# * **objects** - у большинства клиентов в собственности от 3-7 объектов, также есть и пользователи, у которых нет собственности.
# * **balance** - у большинства клиентов небольшой баланс - до 130000 руб. также у четверти клиентов баланс 0. Максимальный счет на ~250 тыс. руб.
# * **products** - банк предоставляет возможность использования до 4 продуктов - большинство клиентов пользуется только 1-2 продуктами банка.
# * **creditcard** - большинство клиентов оформили себе кредитную карту в банке.
# * **loyalty** - больше половины клиентов являются активными пользователями услуг банка.
# * **estimated_salary** - минимальная зп у клиента 11 руб. - это странно, в среднем бользователи получабтся поряка 100 тыс. рублей. Максимальная зп у клиента - 200 тыс. руб.
# * **churn** - около 20% клиентов перестали пользоваться услугами банка.
# * **gender_bul** - мужчин и женщин среди клиентов банка примерно одинаковое количество, но мужчин все-таки немного больше.
# * **city_numb** - большая часть клиентов находится в Ярославле и Ростове Великом, и примерная четверая часть клиентов

# %% [markdown]
# ### Распределения признаков для оттока и действующих клиентов банка

# %%
ax = data.groupby('churn').median().T
ax
# Out:
# churn                    0          1
# score               653.00     646.00
# age                  36.00      45.00
# objects               5.00       5.00
# balance           92072.68  109349.29
# products              2.00       1.00
# creditcard            1.00       1.00
# loyalty               1.00       0.00
# estimated_salary  99645.04  102460.84
# gender_bul            1.00       0.00
# city_numb             1.00       2.00

# %%
import seaborn as sns
for column in data.columns:
    plt.figure(figsize=(12, 5)) 
    
    sns.distplot(data[data['churn']==0][column], bins=10)
    sns.distplot(data[data['churn']==1][column], bins=10)
    plt.title(column)
    plt.show()

    sns.boxplot(x="churn", y=data[column], data=data) 
    plt.title(column)
    plt.show()
    
import warnings
warnings.filterwarnings('ignore')
# Out:
# /opt/conda/lib/python3.7/site-packages/statsmodels/nonparametric/kde.py:487: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# /opt/conda/lib/python3.7/site-packages/statsmodels/nonparametric/kdetools.py:34: RuntimeWarning:
#
# invalid value encountered in double_scalars

# %% [markdown]
# * **score** - отток клиента не зависит от кредитого скоринга, медианное значение у тех, кто ушел в отток и действующих клиентов банка ~650 баллов.
# * **age** - уходят в основном более зрелые клиенты от 40 лет.
# * **objects** - у клиентов, которые уходят диапазон объектов в собственности шире - от 2-8. У тех, кто остается в основном от 3 до 7.
# * **balance** - баланс на счете у отточников немного выше, но особой разницы в балансе нет.
# * **products** - в основном цходят клиенты, которые пользуются только 1 продуктом банка.
# * **creditcard** - перестают пользоваться услугами банка как те, у кого оформлена кредитная карта, так и без нее.
# * **loyalty** - уходят в основном неактиыне клиенты.
# * **estimated_salary** - зп тех, кто перестает пользоваться услугами банка немного выше тех, кто остается с банком.
# * **gender_bul** - уходят в основном женщины.
# * **city_numb** - большинство отточных клиентов из Ростова Великого.

# %% [markdown]
# ### Распределения признаков по городам

# %%
ax = data.groupby('city_numb').mean().T
ax
# Out:
# city_numb                    1              2             3
# score               649.668329     651.453567    651.333872
# age                  38.511767      39.771622     38.890997
# objects               5.004587       5.009964      5.032297
# balance           62092.636516  119730.116134  61818.147763
# products              1.530913       1.519729      1.539362
# creditcard            0.706621       0.713830      0.694792
# loyalty               0.516753       0.497409      0.529673
# estimated_salary  99899.180814  101113.435102  99440.572281
# churn                 0.161548       0.324432      0.166734
# gender_bul            0.549063       0.524512      0.560355

# %%
for column in data.columns:
    plt.figure(figsize=(12, 5))
    
    sns.barplot(x='city_numb', y=data[column], data=data) 
    plt.title(column)
    plt.show()
    
    sns.boxplot(x='city_numb', y=data[column], data=data) 
    plt.title(column)
    plt.show()

# %%
ax = data.groupby('city_numb').median().T
ax
# Out:
# city_numb                1          2         3
# score               653.00     651.00    651.00
# age                  37.00      38.00     37.00
# objects               5.00       5.00      5.00
# balance           62153.50  119703.10  61710.44
# products              1.00       1.00      2.00
# creditcard            1.00       1.00      1.00
# loyalty               1.00       0.00      1.00
# estimated_salary  99132.31  102397.22  99984.86
# churn                 0.00       0.00      0.00
# gender_bul            1.00       1.00      1.00

# %% [markdown]
# * **score** - баллы кредитного скоринга во всех 3 городах практически одинаковые, около ~650 баллов в среднем
# * **age** - средний возрат пользователей по городам 38-39 лет, больше пожилых людей в Ярославле, которые пользуются услугами банка
# * **objects** - в среднем по 5 объектов собственности у клиентов в каждом городе, но в Рыбинске у большей части пользователей количество объектов в собственности от 3-8,в Ростове Великом от 2-8,  а в Ярославле от 2-7.
# * **balance** - самый высокий баланс на счету у клиентов в Ростове Великом - 119 тыс. руб в среднем у клиентов, в Ярославле и Рыбинске примерно одинаково количество - около 62 тыс. руб.
# * **products** - в Рыбинске в среднем клиент пользуется 2 продуктами, тогда как в остальных городах - по 1. Как правило, пользователи во всех городах пользуются до 3 продуктов банка, больше - это редкость.
# * **creditcard** - в основном пользователи все городов используют крединую карту банка.
# * **loyalty** - в Ярославле и Рыбинске большинство клиентов - активные, в Ростове Великом - наоборот.
# * **estimated_salary** - средняя зарплата у клиентов мало отличается друг от друга в городах. В среднем около 100 тыс. руб.
# * **churn** - большинство отточных клиентов из Ростова Великого.
# * **gender_bul** - во всех клиентов мужчин больше, чм женщин.

# %% [markdown]
# ### Корреляционный анализ данных

# %%
plt.figure(figsize=(13, 9))
cm = data.corr()  
sns.heatmap(cm, annot = True, square=True);

# %% [markdown]
# * Мультиколлинеарности в нашей матрице нет.
# * Положительная корреляция признаков `age` и `churn` - то есть чем старше клиент, тем больше вероятность, что он уйдет в отток.
# * Отрицательная корреляция у признаков `products` и `balance` - то есть чем больше баланс на счете клиента, тем меньшим количеством продуктов он пользуется.

# %% [markdown]
# ## Сегментация пользователей на основании количества потребляемых продуктов

# %% [markdown]
# ### Оценка оттока клиентов для каждого сегмента пользователей

# %% [markdown]
# По исходным данным у нас 2 сегмента пользователей:
#     - клиенты, которые пользуются 1 продуктом банка
#     - клиенты, которые пользуются 2 и более продуктами банка

# %%
def segment(row):
    if row['products'] == 1:
        return '0'
    else:
        return '1'

data['segment'] = data.apply(segment, axis=1)
data['segment'] = data['segment'].astype('int')
data.head()
# Out:
#    score  age  objects    balance  products  creditcard  loyalty  \
# 0    619   42        2       0.00         1           1        1
# 1    608   41        1   83807.86         1           0        1
# 2    502   42        8  159660.80         3           1        0
# 3    699   39        1       0.00         2           0        0
# 4    850   43        2  125510.82         1           1        1
#
#    estimated_salary  churn  gender_bul  city_numb  segment
# 0         101348.88      1           0          1        0
# 1         112542.58      0           0          3        0
# 2         113931.57      1           0          1        1
# 3          93826.63      0           0          1        1
# 4          79084.10      0           0          3        0

# %%
data.groupby('segment').agg({'churn':'mean'}).reset_index()
# Out:
#    segment     churn
# 0        0  0.277144
# 1        1  0.127746

# %%
plt.figure(figsize=(12, 5))
    
sns.barplot(x='segment', y=data['churn'], data=data) 
plt.title('Отток клиентов для каждого сегмента пользователя')
plt.show()

# %% [markdown]
# * около 28% пользователей, которые пользуются только 1 продуктом банка уходят в отток
# * всего 13% пользователей, которые пользуются 2 и более продуктами - уходят в отток

# %% [markdown]
# ### Портрет клиента для каждого сегмента

# %%
ax = data.groupby('segment').median().T
ax
# Out:
# segment                    0          1
# score                651.000     652.00
# age                   38.000      37.00
# objects                5.000       5.00
# balance           111886.035       0.00
# products               1.000       2.00
# creditcard             1.000       1.00
# loyalty                1.000       1.00
# estimated_salary   99226.830  100862.45
# churn                  0.000       0.00
# gender_bul             1.000       1.00
# city_numb              2.000       1.00

# %%
import seaborn as sns
for column in data.columns:
    plt.figure(figsize=(12, 5)) 
    
    sns.distplot(data[data['segment']==0][column], bins=10)
    sns.distplot(data[data['segment']==1][column], bins=10)
    plt.title(column)
    plt.show()

    sns.boxplot(x="segment", y=data[column], data=data) 
    plt.title(column)
    plt.show()
    
warnings.filterwarnings('ignore')
# Out:
# /opt/conda/lib/python3.7/site-packages/statsmodels/nonparametric/kde.py:487: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# /opt/conda/lib/python3.7/site-packages/statsmodels/nonparametric/kdetools.py:34: RuntimeWarning:
#
# invalid value encountered in double_scalars
# /opt/conda/lib/python3.7/site-packages/statsmodels/nonparametric/kde.py:487: RuntimeWarning:
#
# invalid value encountered in true_divide
#
# /opt/conda/lib/python3.7/site-packages/statsmodels/nonparametric/kdetools.py:34: RuntimeWarning:
#
# invalid value encountered in double_scalars

# %% [markdown]
# Портрет клиента для каждого сегмента:
#
# * **score** - баллы кредитного скоринга в сегментах практически одинаковые, среднее значение ~650 баллов;
# * **age** - средний возрат в сегментах 37-38 лет, но во втором сегмента больше пожилых людей от 60 лет;
# * **objects** - в большинстве своем пользователи 1 сегмента имеют в собственности от 2-7 объектов недвижимости, а вот во 2 сегмента - от 3-8 объектов;
# * **balance** - в первом сегменте у большинства пользователей есть дебиторский счет на котором ~ 100 руб. в среднем, а у вот у большинства пользователей из 2 сегмента в основном нет дебиторского счета, но также есть пользователи, у которых на счета баланс до 250 тыс. руб.
# * **products** - во втором сегменте пользователи чаще пользуются 2 продуктами, гораздо реже - 3 или 4 продкута банка
# * **creditcard** - кредитные карты используют как клиенты 1 сегмента, так и 2.
# * **loyalty** - уровень зп в сегментах примерно одинаковый, в среднем ~100 тыс. рую
# * **gender_bul** - в большиснвте своем в 1 и 2 сегментах пользователи - мужчины
# * **city_numb** - в 1 сегменте преоладают пользователи из Ростова Великого, во втором - из Ярослаля.

# %% [markdown]
# ## Проверка статистических гипотез

# %% [markdown]
# ### Проверка основной гипотезы

# %% [markdown]
# **Гипотеза H0** - доход пользователей, которые пользуются 1 продуктом банка НЕ отличается (то есть равен) доходу пользователей, которые пользуются 2 продуктами банка
#
# **Гипотеза H1** - доход пользователей, которые пользуются 1 продуктом банка отличается от доходов пользователей, которые пользуются 2 продуктами банка

# %%
one_product = data[data['products'] == 1]
two_product = data[data['products'] == 2]

# %%
def sampling(data, column):
    plt.figure(figsize=(12, 5)) 
    print(data[column].describe())
    
    sns.distplot(data[column])
    plt.show()
    
sampling(one_product, 'estimated_salary')
sampling(two_product, 'estimated_salary')
# Out:
# count      5084.000000
# mean      99487.256851
# std       57363.626412
# min          11.580000
# 25%       50414.515000
# 50%       99226.830000
# 75%      148212.695000
# max      199970.740000
# Name: estimated_salary, dtype: float64
# count      4590.000000
# mean     100452.012821
# std       57790.799984
# min          90.070000
# 25%       50797.287500
# 50%      100738.855000
# 75%      150151.460000
# max      199992.480000
# Name: estimated_salary, dtype: float64

# %% [markdown]
# **Проверка на выбросы**

# %%
one_product.boxplot('estimated_salary')
plt.xlabel('Доход пользователей, которые пользуются 1 продуктом')
plt.show()

two_product.boxplot('estimated_salary')
plt.xlabel('Доход пользователей, которые пользуются 2 продуктами')
plt.show()

# %% [markdown]
# **Проверим дисперсии выборок**

# %%
print(np.var(one_product['estimated_salary']))
print(np.var(two_product['estimated_salary']))
# Out:
# 3289938391.6508718
# 3339048942.6448092

# %% [markdown]
# **Распределение признаков в каждой выборке соответствует нормальному распределению, стандартное отклонение признака в выборках также примерно равны. Чтобы проверить гипотезу о равенстве среднего двух генеральных совокупностей по взятым из них выборкам,применим метод scipy.stats.ttest_ind()**

# %%
one_product_sal = one_product['estimated_salary']
two_product_sal = two_product['estimated_salary']

from scipy import stats as st

results = st.ttest_ind(one_product_sal, two_product_sal, equal_var = True)
print('p-значение: ', results.pvalue)
print('пороговое значение alpha = 0.05')
# Out:
# p-значение:  0.41047183624949335
# пороговое значение alpha = 0.05

# %% [markdown]
# ***Гипотезу H0 отвергнуть не можем***, принимаем, что доход пользователей, которые пользуются 1 продуктом банка равен доходу пользователей, которые пользуются 2 продуктами банка

# %% [markdown]
# ### Проверка дополнительной гипотезы

# %% [markdown]
# **Гипотеза H0** - доход пользователей из 1 сегмента НЕ отличается (то есть равен) доходу пользователей из 2 сегмента
#
# **Гипотеза H1** - доход пользователейиз 1 сегмента отличается от доходов пользователей из 2 сегмента

# %%
one_segment = data[data['segment'] == 0]
two_segment = data[data['segment'] == 1]

# %%
sampling(one_segment, 'estimated_salary')
sampling(two_segment, 'estimated_salary')
# Out:
# count      5084.000000
# mean      99487.256851
# std       57363.626412
# min          11.580000
# 25%       50414.515000
# 50%       99226.830000
# 75%      148212.695000
# max      199970.740000
# Name: estimated_salary, dtype: float64
# count      4916.000000
# mean     100713.829329
# std       57661.187164
# min          90.070000
# 25%       51659.295000
# 50%      100862.450000
# 75%      150176.925000
# max      199992.480000
# Name: estimated_salary, dtype: float64

# %% [markdown]
# **Проверка на выбросы**

# %%
one_segment.boxplot('estimated_salary')
plt.xlabel('Доход пользователей из 1 сегмента')
plt.show()

two_segment.boxplot('estimated_salary')
plt.xlabel('Доход пользователей из 2 сегмента')
plt.show()

# %% [markdown]
# **Проверим дисперсии выборок**

# %%
print(np.var(one_segment['estimated_salary']))
print(np.var(two_segment['estimated_salary']))
# Out:
# 3289938391.6508718
# 3324136180.4029136

# %%
one_segment_sal = one_segment['estimated_salary']
two_segment_sal = two_segment['estimated_salary']

from scipy import stats as st

results = st.ttest_ind(one_segment_sal, two_segment_sal, equal_var = True)
print('p-значение: ', results.pvalue)
print('пороговое значение alpha = 0.05')
# Out:
# p-значение:  0.28633776454408016
# пороговое значение alpha = 0.05

# %% [markdown]
# ***Гипотезу H0 отвергнуть не можем***, принимаем, что доход пользователей из 1 сегмента равен доходу пользователей из 2 сегмента.

# %% [markdown]
# ## Модель прогнозирования оттока клиентов

# %% [markdown]
# ### Обучение модели на train-выборке

# %% [markdown]
# **Разбиваем данные на обучающую и валидационную выборки**

# %%
# Разделим наши данные на признаки (матрица X) и целевую переменную (y)
X = data.drop('churn', axis = 1)
y = data['churn']

# Разбиваем данные на обучающую и валидационную выборки
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %% [markdown]
# **Обучаем модель на train-выборке логистической регрессией**

# %%
from sklearn.linear_model import LogisticRegression

# Задаем алгоритм для нашей модели
lr_model = LogisticRegression(random_state=0)

# Обучаем модель
lr_model.fit(X_train, y_train)

# Делаем прогноз для объектов из валидационного набора данных
lr_predictions = lr_model.predict(X_test)
lr_probabilities = lr_model.predict_proba(X_test)[:,1]

warnings.filterwarnings('ignore')
# Out:
# /opt/conda/lib/python3.7/site-packages/sklearn/linear_model/logistic.py:432: FutureWarning:
#
# Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.

# %% [markdown]
# **Обучаем модель на train-выборке случайным лесом**

# %%
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier

# Задаем алгоритм для новой модели на основе алгоритма случайного леса
rf_model = RandomForestClassifier(n_estimators = 100, random_state = 0)

# Обучаем модель случайного леса
rf_model.fit(X_train, y_train)

# Делаем прогнозы
rf_predictions = rf_model.predict(X_test)
rf_probabilities = rf_model.predict_proba(X_test)[:,1]

# %% [markdown]
# ### Оценка и сравнение метрик на валидационной выборке

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.metrics import roc_auc_score

# Функция,, которая будет выводить наши метрики
def print_all_metrics(y_true, y_pred, y_proba, title = 'Метрики классификации'):
    print(title)
    print('\tAccuracy: {:.2f}'.format(accuracy_score(y_true, y_pred)))
    print('\tPrecision: {:.2f}'.format(precision_score(y_true, y_pred)))
    print('\tRecall: {:.2f}'.format(recall_score(y_true, y_pred)))
    print('\tF1: {:.2f}'.format(f1_score(y_true, y_pred)))
    
print_all_metrics(y_test, lr_predictions, lr_probabilities, title = 'Метрики для модели логистической регрессии:')
print_all_metrics(y_test, rf_predictions, rf_probabilities, title = 'Метрики для модели случайного леса:')
# Out:
# Метрики для модели логистической регрессии:
# 	Accuracy: 0.79
# 	Precision: 0.37
# 	Recall: 0.07
# 	F1: 0.12
# Метрики для модели случайного леса:
# 	Accuracy: 0.86
# 	Precision: 0.74
# 	Recall: 0.49
# 	F1: 0.59

# %% [markdown]
# Метрики для модели случайного леса показали себя лучше в сравнении с метриками для модели логистической регрессии.

# %% [markdown]
# ## Кластеризация клиентов банка

# %% [markdown]
# ### Стандартизация данных. Матрица расстояний и дендограмма

# %%
from sklearn.preprocessing import StandardScaler

sc = StandardScaler() # создаём объект класса scaler (нормализатор)
X_sc = sc.fit_transform(X) # обучаем нормализатор и преобразуем набор данных
print(X_sc[:2])
# Out:
# [[-0.32622142  0.29351742 -1.04175968 -1.22584767 -0.91158349  0.64609167
#    0.97024255  0.02188649 -1.09598752 -0.90188624 -0.98333878]
#  [-0.44003595  0.19816383 -1.38753759  0.11735002 -0.91158349 -1.54776799
#    0.97024255  0.21653375 -1.09598752  1.51506738 -0.98333878]]

# %%
from scipy.cluster.hierarchy import dendrogram, linkage 
linked = linkage(X_sc, method = 'ward')

# %%
plt.figure(figsize=(15, 10))  
dendrogram(linked, orientation='top')
plt.show()

# %% [markdown]
# На основании полученной дендограммы можно предположить, что можно выделить 3 кластера.

# %% [markdown]
# ### Прогноз кластеров

# %%
from sklearn.cluster import KMeans

# задаём модель k_means с числом кластеров 3
km = KMeans(n_clusters = 3)

# прогнозируем кластеры для наблюдений
labels = km.fit_predict(X_sc)

# сохраняем метки кластера в поле нашего датасета
data['cluster_km'] = labels
data.head()
# Out:
#    score  age  objects    balance  products  creditcard  loyalty  \
# 0    619   42        2       0.00         1           1        1
# 1    608   41        1   83807.86         1           0        1
# 2    502   42        8  159660.80         3           1        0
# 3    699   39        1       0.00         2           0        0
# 4    850   43        2  125510.82         1           1        1
#
#    estimated_salary  churn  gender_bul  city_numb  segment  cluster_km
# 0         101348.88      1           0          1        0           1
# 1         112542.58      0           0          3        0           2
# 2         113931.57      1           0          1        1           0
# 3          93826.63      0           0          1        1           0
# 4          79084.10      0           0          3        0           1

# %% [markdown]
# ### Распределение признаков для кластеров

# %%
ax = data.groupby('cluster_km').median().T
ax
# Out:
# cluster_km                0           1           2
# score                652.00     651.000     652.000
# age                   37.00      38.000      38.000
# objects                5.00       5.000       5.000
# balance                0.00  111545.465  112684.870
# products               2.00       1.000       1.000
# creditcard             1.00       1.000       0.000
# loyalty                1.00       0.000       1.000
# estimated_salary  100862.45   98096.985  101356.255
# churn                  0.00       0.000       0.000
# gender_bul             1.00       1.000       1.000
# city_numb              1.00       2.000       2.000
# segment                1.00       0.000       0.000

# %%
for column in data.columns:
    plt.figure(figsize=(12, 5)) 
    sns.distplot(data[data['cluster_km']==0][column], bins=10, kde=False)
    sns.distplot(data[data['cluster_km']==1][column], bins=10, kde=False)
    sns.distplot(data[data['cluster_km']==2][column], bins=10, kde=False)
    plt.title(column)
    plt.show()
    
    sns.boxplot(x='cluster_km', y=data[column], data=data) 
    plt.title(column)
    plt.show()

# %% [markdown]
# Рассматрим распределение признаков в разрезе кластеров:
#
# * **score** - баллы кредитного скоринга для клиентов всех кластеров в большинстве своем примерно одинаковы ~650 быллов;
# * **age** - средний возраст у клиентов в каждом кластере также не сильно отличается 36-38 лет, НО в 3 кластере больше пожилых людей от 60 лет;
# * **objects** - в 1 и 3 кластере у клиентов в среднем от 3-8 объектов недвижимости, а во втором кластере от 2-7 объектов;
# * **balance** - в 1 и 2 кдастере у большинства клиентов не заведен дебиторский счет и 0 баланс, соответственно, а в 3 кластере в среднем баланс клиента составляет чуть больше 110 тыс. руб.
# * **products** - в 1 и 2 кластере в осносном клиенты пользуются 1 продуктом банка, во 2 кластере в среднем - 2-мя, иногда больше;
# * **creditcard** - большинство клиентов всех кластеров используют кредитные карты;
# * **loyalty** - клиенты 1 и 2 кластера в большинстве - активные, в 1 - нет;
# * **estimated_salary** - уровень зп у клиентов всех кластеров порядка 100 тыс. руб.
# * **churn** - большинство клиентов в каждом кластере остаетсся клиентом банка;
# * **gender_bul** - во всех кластерах больше клиентов мужчин;
# * **city_numb** - клиенты 1 и 2 кластера в основном из Ярославля, в 3 - из Ростова Великого;
# * **segment** - клиенты 1 и 2 кластера в основном из 1 сегмента, то есть пользуются 1 продуктом банка, а в 3 кластере - из второго сегмента, то есть пользуются 2 продуктами банка.

# %% [markdown]
# ### Доля оттока для каждого кластера

# %%
data_cluster_gr = data.groupby('cluster_km')['churn'].mean().to_frame().reset_index()
data_cluster_gr
# Out:
#    cluster_km     churn
# 0           0  0.127746
# 1           1  0.276970
# 2           2  0.277556

# %%
plt.figure(figsize=(12, 5)) 
sns.barplot(x="cluster_km", y="churn", data=data_cluster_gr);

# %% [markdown]
# Чаще всего перестают пользоваться услугами банка клиенты ииз 1 и 3 кластера, а самые надежные клиенты в кластере 2.

# %% [markdown]
# ## Выводы и рекомендации

# %% [markdown]
# **Цель заказчика** - определить основные целевые аудитрии и разработать под них целевые программы
#
# 1. При **изучении данных** нашли пропуски в данных `balance` - заменили на 0, так как вероятнее всего это клиенты, у которых отсутствует дебиторский счет.
#
# 2. Провели **исследовательский анализ данных**
#
#     2.1 Рассмотрели ***признаки клиентов банка***:
#
#     В большинстве своем клиенты банка - это зрелые люди из Ярославля или Ростова Великого, мужчины и женщины, от 32-44 лет, имеющие в собственности от 3-7 объектов недвижимости с балансом на счете в банке порядка 100-130 тыс. руб. Это активные клиенты, пользуются 1-2 продуктами банка, имеют кредитную карту банка, получают зп порядка 100 тыс. рублей. Около 20% перестают пользоваться со временем услугами банка.
#
#     2.2 Рассмотрели ***признаки в разрезе клиентов оттока***, которые перестают пользоваться услугами банка:
#
#     Перестают пользоваться услугами банка в основном зрелые клиенты от 40 лет из Ростова Великого, чаще женщины. У таких клиентов в собственности от 2-8 объектов недвижимости, они неактивные пользователи, максимум используют 1 продукт банка, имеют средний баланс на счете порядка 110 тыс. руб., и заработную плату порядка 100 тыс. руб.
#
#     2.3 Рассмотрели ***признаки в разрезе местоположения клиентов банка по городам***:
#     * ***Клиенты в Ярославле*** - это в большинстве зрелые люди 38-39 лет, но также часто можно встретить и клиентов старше 60 лет, имеющих в собственности от 2-7 объектов недвижимости с балансом на счете банка порядка 60 тыс. руб. Это активные клиенты банка, чаще всего пользуются 1 продуктом, имеют кредитную карту и заработную плату порядка 100 тыс. рублей.
#
#     * ***Клиенты в Ростове Великом*** - это зрелые люди 38-39 лет, имеющих в собственности от 2-8 объектов недвижимости с балансом на счете банка около 120 тыс. рублей (что почти в 2 раза выше, чем в остальных городах). Чаще всего в Ростове клиенты неактивные, пользуются всего 1 продуктом банка, имеют кредитную карту, заработную плату порядка 100 тыс. рублей и также клиенты из Ростова чаще других перестают пользоваться услугами банка и уходят в отток.
#
#     * ***Клиенты в Рыбинске*** - это зрелые люди 38-39 лет, имеющих в собственности от 3-8 объектов недвижимости (нижний порог выше, чем в остальных городах) с балансом на счете банка около 60 тыс. рублей. Чаще всего в Рыбинске клиенты активные, пользуются 2 продуктами и больше банка, имеют кредитную карту, заработную плату порядка 100 тыс. рублей.
#
# 3. Провели **корреляционный анализ** данных, выявили зависимости:
#     - положительная корреляция признаков `age` и `churn` - то есть чем старше клиент, тем больше вероятность, что он уйдет в отток.
#     - отрицательная корреляция у признаков `products` и `balance` - то есть чем больше баланс на счете клиента, тем меньшим количеством продуктов он пользуется.
#
#
# 4. **Сегментировали клиентов** по количеству используемых продуктов:
#     - около 28% пользователей, которые пользуются только 1 продуктом банка уходят в отток
#     - всего 13% пользователей, которые пользуются 2 и более продуктами - уходят в отток
#
#
# 5. Составилии **портрет клиента** для каждого сегмента:
#
#     * ***Сегмент 1***, клиенты, которые пользуются 1 продуктом банка - это клиенты 37-38 лет, имеющих в собственности от 2-7 объектов недвижимости с дебиторскоим счетом в банке, на котором около 100 тыс. руб. Как правило это активный клиент с уровенем зп порядка 100 тыс. руб, имеет кредитную карты банка, чаще живет в Ростове Великом.
#
#     * ***Сегмент 2***, клиенты, которые пользуются 2 продуктами банка - это клиенты около 40 лет и старше,  имеющих в собственности от 3-8 объектов недвижимости. Как правило такие клиенты не открывают дебиторский счет, но все равно являются активными пользователями банка, имеют кредитную карту и уровень зарплаты порядка 100 тыс. руб. Чаще это клиенты из Ярославля.
#
#
# 6. Проверили **статистические гипотезы**:
#
#     * Гипотеза различия дохода между теми клиентами, которые пользуются двумя продуктами банка, и теми, которые пользуются одни - доход пользователей не отличается от количества используемых продуктов банка;
#
#     * Гипотеза различия дохода пользователей из 1 сегмента и дохода пользователей из 2 сегмента - доход пользователей из 1 сегмента равен доходу пользователей из 2 сегмента.
#
#
# **Рекомендации**
# 1. Для сокращения оттока клиентов в целом по банку особое внимание следуюет уделить клиентам от 40 лет, которые попали в категорию неактивных пользователей и используют всего 1 продукт банка, для этого:
# - провести маркетинговую компанию по увеличению пользования продуктами банка, возможно, стоит сделать скидку на использование 2 и более продуктов или предложить другие бонусы
# - При попадании клиента в категорию неактивных пользователей - провести анкетирование и узнать причины, по результатам провести маркетинговую кампанию по увеличению пользовательской активности
# - При проведении маркетинговых кампаний особое внимание уделить клиентам из г. Ростова Великого, так как там самый высокий процент отточных клиентов.

# %% [markdown]
# * Дополнительно разработана **модель прогнозирования оттока клиентов** с основными метриками - лучше всего себя показала модель случайного леса;
# * Провела **кластеризацию клиентов** - с помощью дендограммы выделила 3 кластера, провела EDA признаков клиентов банка в разрезе кластеров, выяснили, что чаще всего перестают пользоваться услугами банка клиенты из 1 и 3 кластера, а самые надежные клиенты в кластере 2. (подробное описание признаков по кластерам можно посмотреть в п. 7.3)
#
#
# * **Пожелания относительно тех. задания к схожим проектам на будущее** - в задании указывается деление клиентов на 2 сегмента - те, кто пользуется 1 продуктом и те, кто пользуется 2 продуктами. В дальнейшем для извбежания неточностей просьба обратить внимание, что продуктов может быть больше 2-х, как в данном случае, их 4. В таких случая просьба отдельно отмечать, причислять ли нам тех, кто пользуется 3 и 4 продуктами ко 2-му сегменту или, может быть, его нужно будет выделить отдельно. Такой подход увеличит точность расчетов и сэкономит время на обсуждение перед началом работы, спасибо 🤗
